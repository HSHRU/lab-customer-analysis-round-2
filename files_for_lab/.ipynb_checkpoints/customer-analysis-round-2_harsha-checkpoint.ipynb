# %% [markdown]
# # Lab | Customer Analysis Round 2

# %%
import pandas as pd
import numpy as np
# import os
# working_directory = os.getcwd()
# print(working_directory)

# %% [markdown]
# ### Dealing with the data

# %%
#### 1.show the dateframe shape

# %%
cus_anlys_r2 = pd.read_csv('./csv_files/marketing_customer_analysis.csv')
display(cus_anlys_r2.head())
cus_anlys_r2.shape
print('DataFrame Shape :', cus_anlys_r2.shape)
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %% [markdown]
# ### 2. Standardize header names.

# %% [markdown]
# #### to standerdise headers can be done by using different ways, we are using for loop and range for that

# %%
cols = []
for i in range(len(cus_anlys_r2.columns)):
    cols.append(cus_anlys_r2.columns[i].lower())
cus_anlys_r2.columns = cols
display(cus_anlys_r2.columns)

display(cus_anlys_r2)
# Out:
# Index(['unnamed: 0', 'customer', 'state', 'customer lifetime value',
#        'response', 'coverage', 'education', 'effective to date',
#        'employmentstatus', 'gender', 'income', 'location code',
#        'marital status', 'monthly premium auto', 'months since last claim',
#        'months since policy inception', 'number of open complaints',
#        'number of policies', 'policy type', 'policy', 'renew offer type',
#        'sales channel', 'total claim amount', 'vehicle class', 'vehicle size',
#        'vehicle type'],
#       dtype='object')
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# ...

# %% [markdown]
# #### The unnamed row is an additional information about rows which is not required in this. So we can drop that by using drop functionm

# %%
cus_anlys_r2 = cus_anlys_r2.drop(['unnamed: 0'], axis=1)

cus_anlys_r2
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective to date employmentstatus gender  income  ...  \
# ...

# %% [markdown]
# #### dropping dupplicates is one of the part of data cleaning. by this command we can takeout the duplicate or repeated data.
#
# #### by doing this you can observe that number of rows in a data has been reduced from 10910 rows to 10873 rows

# %%
cus_anlys_r2.drop_duplicates()
cus_anlys_r2 = cus_anlys_r2.drop_duplicates()
cus_anlys_r2
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective to date employmentstatus gender  income  ...  \
# ...

# %% [markdown]
# ### 3. Which columns are numerical?
#
# #### to know the numerical variables in the data we can use the following command
#
# ##### we can see that 8 of them are numerical values

# %%
cus_anlys_r2._get_numeric_data().T
# Out:
#                                      0            1           2      \
# customer lifetime value         4809.21696  2228.525238  14947.9173
# income                         48029.00000     0.000000  22139.0000
# monthly premium auto              61.00000    64.000000    100.0000
# months since last claim            7.00000     3.000000     34.0000
# months since policy inception     52.00000    26.000000     31.0000
# number of open complaints          0.00000     0.000000      0.0000
# number of policies                 9.00000     1.000000      2.0000
# total claim amount               292.80000   744.924331    480.0000
#
#                                       3             4             5      \
# customer lifetime value        22332.439460   9025.067525   4745.181764
# income                         49078.000000  23675.000000  50549.000000
# monthly premium auto              97.000000    117.000000     61.000000
# ...

# %% [markdown]
# ### 4. Which columns are categorical?

# %% [markdown]
# #### There are defferent  ways to observe the categorical data here we are data types funtion for that
#
# ##### 17 rows are actually catagorical datatypes

# %%
#nominal_attr = df.select_dtypes(include='category').columns

cus_anlys_r2.select_dtypes(['object']).T
#cus_anlys_r2.select_dtypes(include='object').columns


#cus_anlys_r2 = cus_anlys_r2.select_dtypes(include='object').columns
#cus_anlys_r2
# Out:
#                             0              1              2      \
# customer                  DK49336        KX64629        LZ68649
# state                     Arizona     California     Washington
# response                       No             No             No
# coverage                    Basic          Basic          Basic
# education                 College        College       Bachelor
# effective to date         2/18/11        1/18/11        2/10/11
# employmentstatus         Employed     Unemployed       Employed
# gender                          M              F              M
# location code            Suburban       Suburban       Suburban
# marital status            Married         Single         Single
# policy type        Corporate Auto  Personal Auto  Personal Auto
# policy               Corporate L3    Personal L3    Personal L3
# renew offer type           Offer3         Offer4         Offer3
# sales channel               Agent    Call Center    Call Center
# ...

# %% [markdown]
# ### 5. Check and deal with NaN values.

# %% [markdown]
# #### To check and deal with the NaN values here., we use .isna().sum() which actually returns the number of missing values in each column

# %%
cus_anlys_r2.isna().sum()
# Out:
# customer                            0
# state                             614
# customer lifetime value             0
# response                          614
# coverage                            0
# education                           0
# effective to date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim           623
# months since policy inception       0
# number of open complaints         623
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                     608
# vehicle size                      608
# vehicle type                     5465
# ...

# %% [markdown]
# #### shows the percentage of null values in a column

# %%
round(cus_anlys_r2.isna().sum()/len(cus_anlys_r2),4)*100  # shows the percentage of null values in a column
# Out:
# customer                          0.00
# state                             5.65
# customer lifetime value           0.00
# response                          5.65
# coverage                          0.00
# education                         0.00
# effective to date                 0.00
# employmentstatus                  0.00
# gender                            0.00
# income                            0.00
# location code                     0.00
# marital status                    0.00
# monthly premium auto              0.00
# months since last claim           5.73
# months since policy inception     0.00
# number of open complaints         5.73
# number of policies                0.00
# policy type                       0.00
# policy                            0.00
# renew offer type                  0.00
# sales channel                     0.00
# total claim amount                0.00
# vehicle class                     5.59
# vehicle size                      5.59
# ...

# %% [markdown]
# ### 5. Check and deal with NaN values.

# %%
# Replacing/imputing null values
cus_anlys_r2[cus_anlys_r2['vehicle type'].isna()==True].T # checking rows that are null based on a specific column
# Out:
#                                         0              1              4      \
# customer                              DK49336        KX64629        QA50777
# state                                 Arizona     California         Oregon
# customer lifetime value            4809.21696    2228.525238    9025.067525
# response                                   No             No             No
# coverage                                Basic          Basic        Premium
# education                             College        College       Bachelor
# effective to date                     2/18/11        1/18/11        1/17/11
# employmentstatus                     Employed     Unemployed  Medical Leave
# gender                                      M              F              F
# income                                  48029              0          23675
# location code                        Suburban       Suburban       Suburban
# ...

# %%
cus_anlys_r2[cus_anlys_r2['vehicle size'].isna()==True].T# checking rows that are null based on a specific column
# Out:
#                                        87                    88     \
# customer                             ZH92587               CJ51511
# state                                 Oregon               Arizona
# customer lifetime value          8126.766397           13466.92071
# response                                  No                   Yes
# coverage                               Basic                 Basic
# education                            College  High School or Below
# effective to date                    2/22/11               2/23/11
# employmentstatus                    Disabled              Disabled
# gender                                     F                     F
# income                                 14616                 11432
# location code                       Suburban              Suburban
# marital status                       Married               Married
# monthly premium auto                     107                   119
# ...

# %%
nulls_df = pd.DataFrame(round(cus_anlys_r2.isna().sum()/len(cus_anlys_r2),4)*100)
nulls_df

#nulls_df.columns = ['header_name', 'percent_nulls']
#nulls_df
# Out:
#                                    0
# customer                        0.00
# state                           5.65
# customer lifetime value         0.00
# response                        5.65
# coverage                        0.00
# education                       0.00
# effective to date               0.00
# employmentstatus                0.00
# gender                          0.00
# income                          0.00
# location code                   0.00
# marital status                  0.00
# monthly premium auto            0.00
# months since last claim         5.73
# months since policy inception   0.00
# number of open complaints       5.73
# number of policies              0.00
# policy type                     0.00
# policy                          0.00
# renew offer type                0.00
# sales channel                   0.00
# total claim amount              0.00
# vehicle class                   5.59
# vehicle size                    5.59
# ...

# %%
#columns_drop = nulls_df[nulls_df['percent_nulls']>3]['header_name']  # dummy case with 3
#print(columns_drop.values)
#donors = donors.drop(columns_drop, axis=1)  # drop a list of columns DO NOT RUN THIS
#donors = donors.drop(['gender'], axis=1)  # drop a single column DO NOT RUN THIS

# %%
# Replacing/imputing null values
#donors[donors['gender'].isna()==True].head(60) # checking rows that are null based on a specific column

# %%
cus_anlys_r2.isnull().sum()
# Out:
# customer                            0
# state                             614
# customer lifetime value             0
# response                          614
# coverage                            0
# education                           0
# effective to date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim           623
# months since policy inception       0
# number of open complaints         623
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                     608
# vehicle size                      608
# vehicle type                     5465
# ...

# %%
#cus_anlys_r2.loc[df["columns"].isnull(),"columns"] = cus_anlys_r2["columns"].quantile(0.5)
cus_anlys_r2.shape
cus_anlys_r2.isnull()
# Out:
#        customer  state  customer lifetime value  response  coverage  \
# 0         False  False                    False     False     False
# 1         False  False                    False     False     False
# 2         False  False                    False     False     False
# 3         False  False                    False     False     False
# 4         False  False                    False     False     False
# ...         ...    ...                      ...       ...       ...
# 10905     False  False                    False     False     False
# 10906     False  False                    False     False     False
# 10907     False  False                    False     False     False
# 10908     False  False                    False     False     False
# 10909     False   True                    False      True     False
#
#        education  effective to date  employmentstatus  gender  income  ...  \
# ...

# %%
cus_anlys_r2.isnull().sum() # this gives total sum of null values in each column
# Out:
# customer                            0
# state                             614
# customer lifetime value             0
# response                          614
# coverage                            0
# education                           0
# effective to date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim           623
# months since policy inception       0
# number of open complaints         623
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                     608
# vehicle size                      608
# vehicle type                     5465
# ...

# %%
cus_anlys_r2.isnull().sum().sum()    # if we want to just a total number of null values then this command will help
# Out:
# 9155

# %% [markdown]
# # Filling null values

# %%
cus_anlys_r2_fNaN = cus_anlys_r2.fillna(value = 0)
cus_anlys_r2_fNaN
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877           0              6857.519928        0     Basic
#
#       education effective to date employmentstatus gender  income  ...  \
# ...

# %%
cus_anlys_r2_fNaN.isnull().sum().sum() #checking the null values over all NaN values were replaced by zero
# Out:
# 0

# %%
# There are so many other ways to deal with null values 

#cus_anlys_r2.fillna(value = cus_anlys_r2[''].mean())

#cus_anlys_r2.fillna({'response':'btw'})



#cus_anlys_r2 = cus_anlys_r2.dropna(how = 'all') 

#replace 

#cus_anlys_r2 = cus_anlys_r2.replace(to_replace= np.nan, value = '')

#cus_anlys_r2 = cus_anlys_r2.replace(to_replace= '<anyvalue>', value = '<intended value>')

#Interpolate using linear method

#cus_anlys_r2['response'] = cus_anlys_r2['response'].interpolate(method = 'linear')

#Interpolate using limit with forward values

#cus_anlys_r2['response'] = cus_anlys_r2['response'].interpolate(method = 'linear', limit_direction = 'forward')


# data filling with intended values in different columns

# cus_anlys_modi_null = cus_anlys_r2.fillna({
#                          'response' : 'btw',
#                         'months since last claim' :'',
#                         'number of open complaints' : '',
#                         'vehicle class': '',
#                         'vehicle size': '',
#                         'vehicle type': ''
                        
#     })

# cus_anlys_modi_null = cus_anlys_modi_null.replace({
#                                     'state' : '[A-Za-z]',
#                                     'response' : '[A-Za-z]'
                                    
    
#     }),'',regex = True)

# cus_anlys_modi_null = cus_anlys_modi_null.replace(['','','',''], ['','','',''])

# %%
# cus_anlys_r2 = = cus_anlys_r2.fillna({
#                          'response' : '',
#                         'months since last claim' :'',
#                         'number of open complaints' : '',
#                         'vehicle class': '',
#                         'vehicle size': '',
#                         'vehicle type': ''
#                        })


cus_anlys_r2.shape
# Out:
# (10873, 25)

# %% [markdown]
# ### To test the null files I have looked into the files I have a created a Test.

# %%
cus_anlys_r2_test = cus_anlys_r2.fillna({
                            'state' : 'unknown',
                            'response' : 'btw',
                            'months since last claim' :'',
                            'number of open complaints' : '',
                            'vehicle class': '',
                            'vehicle size': '',
                            'vehicle type': 'no info'
                            })
cus_anlys_r2_test
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877     unknown              6857.519928      btw     Basic
#
#       education effective to date employmentstatus gender  income  ...  \
# ...

# %%
cus_anlys_r2.dtypes
# Out:
# customer                          object
# state                             object
# customer lifetime value          float64
# response                          object
# coverage                          object
# education                         object
# effective to date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location code                     object
# marital status                    object
# monthly premium auto               int64
# months since last claim          float64
# months since policy inception      int64
# number of open complaints        float64
# number of policies                 int64
# policy type                       object
# policy                            object
# renew offer type                  object
# sales channel                     object
# total claim amount               float64
# vehicle class                     object
# ...

# %%
cus_anlys_r2_test.isnull()
# Out:
#        customer  state  customer lifetime value  response  coverage  \
# 0         False  False                    False     False     False
# 1         False  False                    False     False     False
# 2         False  False                    False     False     False
# 3         False  False                    False     False     False
# 4         False  False                    False     False     False
# ...         ...    ...                      ...       ...       ...
# 10905     False  False                    False     False     False
# 10906     False  False                    False     False     False
# 10907     False  False                    False     False     False
# 10908     False  False                    False     False     False
# 10909     False  False                    False     False     False
#
#        education  effective to date  employmentstatus  gender  income  ...  \
# ...

# %%
#df['Month'] = pd.DatetimeIndex(df['Date']).month
# dt = pd.date_range("January","March")
# idx =pd.DatetimeIndex(dt)
# cus_anlys_r2= cus_anlys_r2.reindex(idx)
# df

# %% [markdown]
# ### Now I wanted to apply clearing null values as I looked at the test

# %% [markdown]
# ##### After looking at the missing values deeply and by judging on their requirement we can delete the unnecessary file by using the follwing command for a individual data variables.

# %%
import statistics as stats
stats.mode(cus_anlys_r2['state'])
cus_anlys_r2.columns= cus_anlys_r2.columns.str.lower().str.replace(' ', '_')
cus_anlys_r2['state'].fillna(stats.mode(cus_anlys_r2['state']), inplace=True)
cus_anlys_r2['response'].fillna(stats.mode(cus_anlys_r2['response']), inplace=True)
cus_anlys_r2['vehicle_class'].fillna(stats.mode(cus_anlys_r2['vehicle_class']), inplace=True)
cus_anlys_r2['vehicle_size'].fillna(stats.mode(cus_anlys_r2['vehicle_size']), inplace=True)
# Out:
# C:\Users\satur\AppData\Local\Temp\ipykernel_1720\3351604866.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cus_anlys_r2['state'].fillna(stats.mode(cus_anlys_r2['state']), inplace=True)
# C:\Users\satur\AppData\Local\Temp\ipykernel_1720\3351604866.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cus_anlys_r2['response'].fillna(stats.mode(cus_anlys_r2['response']), inplace=True)
# C:\Users\satur\AppData\Local\Temp\ipykernel_1720\3351604866.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
cus_anlys_r2.T
# Out:
#                                         0              1              2      \
# customer                              DK49336        KX64629        LZ68649
# state                                 Arizona     California     Washington
# customer_lifetime_value            4809.21696    2228.525238     14947.9173
# response                                   No             No             No
# coverage                                Basic          Basic          Basic
# education                             College        College       Bachelor
# effective_to_date                     2/18/11        1/18/11        2/10/11
# employmentstatus                     Employed     Unemployed       Employed
# gender                                      M              F              M
# income                                  48029              0          22139
# location_code                        Suburban       Suburban       Suburban
# ...

# %%
cus_anlys_r2 = cus_anlys_r2.fillna({
                           'vehicle_type': 'no_info'
                            })
cus_anlys_r2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10873 entries, 0 to 10909
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       10873 non-null  object
#  1   state                          10873 non-null  object
#  2   customer_lifetime_value        10873 non-null  float64
#  3   response                       10873 non-null  object
#  4   coverage                       10873 non-null  object
#  5   education                      10873 non-null  object
#  6   effective_to_date              10873 non-null  object
#  7   employmentstatus               10873 non-null  object
#  8   gender                         10873 non-null  object
#  9   income                         10873 non-null  int64
#  10  location_code                  10873 non-null  object
#  11  marital_status                 10873 non-null  object
# ...

# %%
cus_anlys_r2
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877  California              6857.519928       No     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# ...

# %% [markdown]
# #### We have to use mean or median for some data variables to find the reasonable values.

# %%
np.mean(cus_anlys_r2['months_since_last_claim'])
# Out:
# 15.145073170731708

# %%
np.median(cus_anlys_r2['months_since_last_claim'])
# Out:
# nan

# %%
cus_anlys_r2['months_since_last_claim'].fillna(np.mean(cus_anlys_r2['months_since_last_claim']), inplace=True)

# %%
np.median(cus_anlys_r2['number_of_open_complaints'])
# Out:
# nan

# %%
np.mean(cus_anlys_r2['number_of_open_complaints'])
# Out:
# 0.3835121951219512

# %% [markdown]
# #### Most of the values are zero therefore we add the median.

# %%
cus_anlys_r2['number_of_open_complaints'].fillna(np.mean(cus_anlys_r2['number_of_open_complaints']), inplace=True)

# %%
cus_anlys_r2.isna().sum()
# Out:
# customer                         0
# state                            0
# customer_lifetime_value          0
# response                         0
# coverage                         0
# education                        0
# effective_to_date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location_code                    0
# marital_status                   0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# policy_type                      0
# policy                           0
# renew_offer_type                 0
# sales_channel                    0
# total_claim_amount               0
# vehicle_class                    0
# vehicle_size                     0
# vehicle_type                     0
# dtype: int64

# %% [markdown]
# ### 6. Datetime format -
#
# ###### Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, consider only January and February.

# %%
cus_anlys_r2['effective_to_date'] = pd.to_datetime(cus_anlys_r2['effective_to_date'], errors='coerce')

# %%
# df['month'] = pd.DatetimeIndex(df['effective_to_date']).month
cus_anlys_r2['month'] = cus_anlys_r2['effective_to_date'].dt.month
cus_anlys_r2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10873 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       10873 non-null  object
#  1   state                          10873 non-null  object
#  2   customer_lifetime_value        10873 non-null  float64
#  3   response                       10873 non-null  object
#  4   coverage                       10873 non-null  object
#  5   education                      10873 non-null  object
#  6   effective_to_date              10873 non-null  datetime64[ns]
#  7   employmentstatus               10873 non-null  object
#  8   gender                         10873 non-null  object
#  9   income                         10873 non-null  int64
#  10  location_code                  10873 non-null  object
#  11  marital_status                 10873 non-null  object
# ...

# %% [markdown]
# ##### below command is used to print a particular month

# %%
cus_anlys_r2.loc[cus_anlys_r2['month'] == 3]
# Out:
# Empty DataFrame
# Columns: [customer, state, customer_lifetime_value, response, coverage, education, effective_to_date, employmentstatus, gender, income, location_code, marital_status, monthly_premium_auto, months_since_last_claim, months_since_policy_inception, number_of_open_complaints, number_of_policies, policy_type, policy, renew_offer_type, sales_channel, total_claim_amount, vehicle_class, vehicle_size, vehicle_type, month]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# ##### where there is no which of month March which named as 3 not existing we show data only for January and February

# %%
cus_anlys_r2[cus_anlys_r2['month'].isin([1,2])]
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877  California              6857.519928       No     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
#newdf = cus_anlys_r2[(cus_anlys_r2.effective_to_date == "") & (cus_anlys_r2.month == "3")]
#newdf
# Out:
# Empty DataFrame
# Columns: [customer, state, customer_lifetime_value, response, coverage, education, effective_to_date, employmentstatus, gender, income, location_code, marital_status, monthly_premium_auto, months_since_last_claim, months_since_policy_inception, number_of_open_complaints, number_of_policies, policy_type, policy, renew_offer_type, sales_channel, total_claim_amount, vehicle_class, vehicle_size, vehicle_type, month]
# Index: []
#
# [0 rows x 26 columns]

# %%
cus_anlys_r2[cus_anlys_r2['month'].isin([1,2])]
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877  California              6857.519928       No     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# ...

# %% [markdown]
# ### Bonus: Put all the previously mentioned data transformations into a function.

# %%
#fill NA
def fillna(table, col, method):
    if method == 'mean':
        table[col].fillna(np.mean(table[col]), inplace=True)
    elif method== 'med':
        table[col].fillna(np.median(table[col]), inplace=True)
    elif method == 'mod':
        table[col].fillna(stats.mode(table[col]), inplace=True)    
    else:
        print('Method not defined')
        
#change Type to Datetime
def col_to_datetime(table, col):
    table[col] = pd.to_datetime(table[col], errors='coerce')
    
#Clean Table
def clean_table(table):  
    table.drop(['Unnamed: 0'], axis=1, inplace=True)
    table.columns= table.columns.str.lower().str.replace(' ', '_')
    col_to_datetime(table, 'effective_to_date')
    fillna(table, 'state', 'mod')
    fillna(table, 'response', 'mod')
    fillna(table, 'vehicle_class', 'mod')
    fillna(table, 'vehicle_size', 'mod')
    fillna(table, 'months_since_last_claim', 'mean')
    fillna(table, 'number_of_open_complaints', 'mean')
    table['vehicle_type'].fillna('Unknown', inplace=True)

# %%
cus_anlys_r2_ = pd.read_csv('./csv_files/marketing_customer_analysis.csv')
clean_table(cus_anlys_r2_)
cus_anlys_r2_.isna().sum()
# Out:
# customer                         0
# state                            0
# customer_lifetime_value          0
# response                         0
# coverage                         0
# education                        0
# effective_to_date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location_code                    0
# marital_status                   0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# policy_type                      0
# policy                           0
# renew_offer_type                 0
# sales_channel                    0
# total_claim_amount               0
# vehicle_class                    0
# vehicle_size                     0
# vehicle_type                     0
# dtype: int64
